# %% [markdown]
# # Descriptive Statistics: The describe() function provides an overview of the 'Value' column's statistical properties. It offers insights into the central tendency, dispersion, and distribution of the investment values.

# %%
import pandas as pd
import matplotlib as plt

# %%
#List of countries to keep
countries_to_keep = ['Ireland', 'Austria', 'Belgium', 'Denmark', 'Finland', 'Greece',
                     'Luxembourg', 'Netherlands', 'Norway', 'Sweden', 'Switzerland']

# %%
# Read the first CSV files into a DataFrame
pd_investment = pd.read_csv('Transport infrastructure_Investment Spending.csv')
# Read the second CSV file into another DataFrame
pd_maintenance = pd.read_csv('Transport infrastructure_Maintenance Spending.csv')
# Read the third CSV file into another DataFrame
pd_capital_value = pd.read_csv('Transport infrastructure_Capital Value.csv')
# Read the second CSV file into another DataFrame
pd_overview = pd.read_csv('Transport infrastructure_Overview.csv')

# %%
# Display rows and columns in the DataFrame
print(pd_investment.shape)
print(pd_maintenance.shape)
print(pd_capital_value.shape)
print(pd_overview.shape)
# Out:
# (19099, 17)
# (11055, 17)
# (6195, 17)
# (11655, 17)

# %%
# Join 4 DataFrames and create only one
concatenate_date = pd.concat([pd_investment,pd_maintenance,pd_capital_value,pd_overview], axis=0, ignore_index = True)
concatenate_date
# Out:
#       COUNTRY  Country        VARIABLE  \
# 0         ALB  Albania  I-INV-TOT-INLD
# 1         ALB  Albania  I-INV-TOT-INLD
# 2         ALB  Albania  I-INV-TOT-INLD
# 3         ALB  Albania  I-INV-TOT-INLD
# 4         ALB  Albania  I-INV-TOT-INLD
# ...       ...      ...             ...
# 47999     CHL    Chile    I-INV-MTN-RD
# 48000     CHL    Chile    I-INV-MTN-RD
# 48001     CHL    Chile    I-INV-MTN-RD
# 48002     CHL    Chile    I-INV-MTN-RD
# 48003     CHL    Chile    I-INV-MTN-RD
#
#                                                Variable    MEASURE  \
# 0      Total inland transport infrastructure investment        NAT
# 1      Total inland transport infrastructure investment        NAT
# 2      Total inland transport infrastructure investment        NAT
# 3      Total inland transport infrastructure investment        NAT
# 4      Total inland transport infrastructure investment        NAT
# ...                                                 ...        ...
# 47999                               Total road spending  EUR_CONST
# 48000                               Total road spending  EUR_CONST
# 48001                               Total road spending  EUR_CONST
# 48002                               Total road spending  EUR_CONST
# 48003                               Total road spending  EUR_CONST
#
#                  Measure  YEAR  Year Unit Code  Unit  PowerCode Code  \
# 0      National currency  2000  2000       ALL   Lek               0
# 1      National currency  2001  2001       ALL   Lek               0
# 2      National currency  2002  2002       ALL   Lek               0
# 3      National currency  2003  2003       ALL   Lek               0
# 4      National currency  2004  2004       ALL   Lek               0
# ...                  ...   ...   ...       ...   ...             ...
# 47999      Constant Euro  2017  2017       EUR  Euro               0
# 48000      Constant Euro  2018  2018       EUR  Euro               0
# 48001      Constant Euro  2019  2019       EUR  Euro               0
# 48002      Constant Euro  2020  2020       EUR  Euro               0
# 48003      Constant Euro  2021  2021       EUR  Euro               0
#
#       PowerCode  Reference Period Code  Reference Period         Value  \
# 0         Units                    NaN               NaN  1.464200e+10
# 1         Units                    NaN               NaN  1.400300e+10
# 2         Units                    NaN               NaN  9.275000e+09
# 3         Units                    NaN               NaN  8.460000e+09
# 4         Units                    NaN               NaN  1.189600e+10
# ...         ...                    ...               ...           ...
# 47999     Units                    NaN               NaN  1.921293e+09
# 48000     Units                    NaN               NaN  1.752731e+09
# 48001     Units                    NaN               NaN  1.910727e+09
# 48002     Units                    NaN               NaN  1.642003e+09
# 48003     Units                    NaN               NaN  1.258650e+09
#
#       Flag Codes              Flags
# 0            NaN                NaN
# 1            NaN                NaN
# 2            NaN                NaN
# 3            NaN                NaN
# 4            NaN                NaN
# ...          ...                ...
# 47999          P  Provisional value
# 48000          P  Provisional value
# 48001          P  Provisional value
# 48002          P  Provisional value
# 48003          P  Provisional value
#
# [48004 rows x 17 columns]

# %%
# Drop specified columns in the new DataFrame
columns_to_drop = ['COUNTRY', 'VARIABLE', 'MEASURE', 'YEAR', 'Unit Code','Unit', 'PowerCode Code', 
                   'PowerCode', 'Reference Period Code','Reference Period', 'Flag Codes', 'Flags']

# %%
# Cleaning process for the first DataFrame (pd_investment)
concatenate_date = concatenate_date.drop(columns=columns_to_drop, axis=1)
concatenate_date
# Out:
#        Country                                          Variable  \
# 0      Albania  Total inland transport infrastructure investment
# 1      Albania  Total inland transport infrastructure investment
# 2      Albania  Total inland transport infrastructure investment
# 3      Albania  Total inland transport infrastructure investment
# 4      Albania  Total inland transport infrastructure investment
# ...        ...                                               ...
# 47999    Chile                               Total road spending
# 48000    Chile                               Total road spending
# 48001    Chile                               Total road spending
# 48002    Chile                               Total road spending
# 48003    Chile                               Total road spending
#
#                  Measure  Year         Value
# 0      National currency  2000  1.464200e+10
# 1      National currency  2001  1.400300e+10
# 2      National currency  2002  9.275000e+09
# 3      National currency  2003  8.460000e+09
# 4      National currency  2004  1.189600e+10
# ...                  ...   ...           ...
# 47999      Constant Euro  2017  1.921293e+09
# 48000      Constant Euro  2018  1.752731e+09
# 48001      Constant Euro  2019  1.910727e+09
# 48002      Constant Euro  2020  1.642003e+09
# 48003      Constant Euro  2021  1.258650e+09
#
# [48004 rows x 5 columns]

# %%
# Use constant euro because it is an exchange rates used by eliminating the effects of foreign currency fluctuations in financial statements
concatenate_date = concatenate_date[concatenate_date['Measure'] == 'Constant Euro']
concatenate_date
# Out:
#        Country                                          Variable  \
# 262    Albania  Total inland transport infrastructure investment
# 263    Albania  Total inland transport infrastructure investment
# 264    Albania  Total inland transport infrastructure investment
# 265    Albania  Total inland transport infrastructure investment
# 266    Albania  Total inland transport infrastructure investment
# ...        ...                                               ...
# 47999    Chile                               Total road spending
# 48000    Chile                               Total road spending
# 48001    Chile                               Total road spending
# 48002    Chile                               Total road spending
# 48003    Chile                               Total road spending
#
#              Measure  Year         Value
# 262    Constant Euro  2000  1.008693e+08
# 263    Constant Euro  2001  9.070534e+07
# 264    Constant Euro  2002  7.692671e+07
# 265    Constant Euro  2003  6.842285e+07
# 266    Constant Euro  2004  9.326190e+07
# ...              ...   ...           ...
# 47999  Constant Euro  2017  1.921293e+09
# 48000  Constant Euro  2018  1.752731e+09
# 48001  Constant Euro  2019  1.910727e+09
# 48002  Constant Euro  2020  1.642003e+09
# 48003  Constant Euro  2021  1.258650e+09
#
# [15997 rows x 5 columns]

# %%
# Countries_to_keep = 'Ireland', 'Austria', 'Belgium', 'Denmark', 'Finland', 'Greece', Luxembourg', 'Netherlands', 'Norway', 'Sweden', 'Switzerland'
concatenate_date = concatenate_date[concatenate_date['Country'].isin(countries_to_keep)]
concatenate_date.to_csv('concatenate_result1.csv', index=False)
concatenate_date
# Out:
#            Country                                          Variable  \
# 1239       Austria  Total inland transport infrastructure investment
# 1240       Austria  Total inland transport infrastructure investment
# 1241       Austria  Total inland transport infrastructure investment
# 1242       Austria  Total inland transport infrastructure investment
# 1243       Austria  Total inland transport infrastructure investment
# ...            ...                                               ...
# 46902  Switzerland                               Total road spending
# 46903  Switzerland                               Total road spending
# 46904  Switzerland                               Total road spending
# 46905  Switzerland                               Total road spending
# 46906  Switzerland                               Total road spending
#
#              Measure  Year         Value
# 1239   Constant Euro  2000  2.198050e+09
# 1240   Constant Euro  2001  2.203724e+09
# 1241   Constant Euro  2002  2.195319e+09
# 1242   Constant Euro  2003  2.259999e+09
# 1243   Constant Euro  2004  2.553691e+09
# ...              ...   ...           ...
# 46902  Constant Euro  2016  6.802047e+09
# 46903  Constant Euro  2017  6.912505e+09
# 46904  Constant Euro  2018  6.894640e+09
# 46905  Constant Euro  2019  7.139519e+09
# 46906  Constant Euro  2020  7.390612e+09
#
# [3538 rows x 5 columns]

# %%
# Drop NaN values, and display information for the first DataFrame
pd.options.display.float_format = '{:.2f}'.format
concatenate_date.dropna(inplace=True)
concatenate_date.to_csv('concatenate_result2.csv', index=False)
concatenate_date
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_10124\2431616253.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   concatenate_date.dropna(inplace=True)
#            Country                                          Variable  \
# 1239       Austria  Total inland transport infrastructure investment
# 1240       Austria  Total inland transport infrastructure investment
# 1241       Austria  Total inland transport infrastructure investment
# 1242       Austria  Total inland transport infrastructure investment
# 1243       Austria  Total inland transport infrastructure investment
# ...            ...                                               ...
# 46902  Switzerland                               Total road spending
# 46903  Switzerland                               Total road spending
# 46904  Switzerland                               Total road spending
# 46905  Switzerland                               Total road spending
# 46906  Switzerland                               Total road spending
#
#              Measure  Year         Value
# 1239   Constant Euro  2000 2198050334.99
# 1240   Constant Euro  2001 2203724449.80
# 1241   Constant Euro  2002 2195318643.66
# 1242   Constant Euro  2003 2259998588.47
# 1243   Constant Euro  2004 2553691459.10
# ...              ...   ...           ...
# 46902  Constant Euro  2016 6802047246.49
# 46903  Constant Euro  2017 6912505087.00
# 46904  Constant Euro  2018 6894640075.30
# 46905  Constant Euro  2019 7139518917.18
# 46906  Constant Euro  2020 7390611955.88
#
# [3010 rows x 5 columns]

# %%
# Display duplicated rows if there are duplicated values
duplicated_rows = concatenate_date[concatenate_date.duplicated()]
duplicated_rows
# Out:
#            Country                                          Variable  \
# 37095      Austria  Total inland transport infrastructure investment
# 37096      Austria  Total inland transport infrastructure investment
# 37097      Austria  Total inland transport infrastructure investment
# 37098      Austria  Total inland transport infrastructure investment
# 37099      Austria  Total inland transport infrastructure investment
# ...            ...                                               ...
# 46860  Switzerland                    Road infrastructure investment
# 46861  Switzerland                    Road infrastructure investment
# 46862  Switzerland                    Road infrastructure investment
# 46863  Switzerland                    Road infrastructure investment
# 46864  Switzerland                    Road infrastructure investment
#
#              Measure  Year         Value
# 37095  Constant Euro  2000 2198050334.99
# 37096  Constant Euro  2001 2203724449.80
# 37097  Constant Euro  2002 2195318643.66
# 37098  Constant Euro  2003 2259998588.47
# 37099  Constant Euro  2004 2553691459.10
# ...              ...   ...           ...
# 46860  Constant Euro  2016 4048150712.15
# 46861  Constant Euro  2017 4092160388.61
# 46862  Constant Euro  2018 4105206716.43
# 46863  Constant Euro  2019 4427652197.65
# 46864  Constant Euro  2020 4640757821.85
#
# [498 rows x 5 columns]

# %%
# Remove duplicated rows (there are 498 rows to eliminate)
concatenate_date = concatenate_date.drop_duplicates()
concatenate_date
# Out:
#            Country                                          Variable  \
# 1239       Austria  Total inland transport infrastructure investment
# 1240       Austria  Total inland transport infrastructure investment
# 1241       Austria  Total inland transport infrastructure investment
# 1242       Austria  Total inland transport infrastructure investment
# 1243       Austria  Total inland transport infrastructure investment
# ...            ...                                               ...
# 46902  Switzerland                               Total road spending
# 46903  Switzerland                               Total road spending
# 46904  Switzerland                               Total road spending
# 46905  Switzerland                               Total road spending
# 46906  Switzerland                               Total road spending
#
#              Measure  Year         Value
# 1239   Constant Euro  2000 2198050334.99
# 1240   Constant Euro  2001 2203724449.80
# 1241   Constant Euro  2002 2195318643.66
# 1242   Constant Euro  2003 2259998588.47
# 1243   Constant Euro  2004 2553691459.10
# ...              ...   ...           ...
# 46902  Constant Euro  2016 6802047246.49
# 46903  Constant Euro  2017 6912505087.00
# 46904  Constant Euro  2018 6894640075.30
# 46905  Constant Euro  2019 7139518917.18
# 46906  Constant Euro  2020 7390611955.88
#
# [2512 rows x 5 columns]

# %%
# Sort by countries
concatenate_date = concatenate_date.sort_values(by='Country')
concatenate_date.reset_index(drop=True, inplace=True)
concatenate_date.to_csv('concatenate_result3.csv', index=False)
concatenate_date
# Out:
#           Country                                           Variable  \
# 0         Austria   Total inland transport infrastructure investment
# 1         Austria  Road infrastructure investment: Of which motorway
# 2         Austria                     Road infrastructure investment
# 3         Austria                     Road infrastructure investment
# 4         Austria                     Road infrastructure investment
# ...           ...                                                ...
# 2507  Switzerland           Inland waterway infrastucture investment
# 2508  Switzerland                  Airport infrastructure investment
# 2509  Switzerland                  Airport infrastructure investment
# 2510  Switzerland                    Rail infrastructure maintenance
# 2511  Switzerland                                Total road spending
#
#             Measure  Year         Value
# 0     Constant Euro  2000 2198050334.99
# 1     Constant Euro  2005  827752905.71
# 2     Constant Euro  2000  623700065.19
# 3     Constant Euro  2001  824303710.04
# 4     Constant Euro  2002  677441716.02
# ...             ...   ...           ...
# 2507  Constant Euro  2004    2173272.40
# 2508  Constant Euro  2000  725757214.25
# 2509  Constant Euro  2002  707079476.19
# 2510  Constant Euro  2005 1126145305.00
# 2511  Constant Euro  2020 7390611955.88
#
# [2512 rows x 5 columns]

# %%
# Display if there are null values
concatenate_date.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2512 entries, 0 to 2511
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Country   2512 non-null   object
#  1   Variable  2512 non-null   object
#  2   Measure   2512 non-null   object
#  3   Year      2512 non-null   int64
#  4   Value     2512 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 98.3+ KB

# %%
# Descriptive statistics
concatenate_date['Value'].describe()
# Out:
# count           2512.00
# mean      4674631895.38
# std      13721309389.31
# min                0.00
# 25%        137572006.85
# 50%        605561732.18
# 75%       1843985724.90
# max     106719485821.09
# Name: Value, dtype: float64

# %%
import statistics
print(statistics.mean(concatenate_date['Value']))
print(statistics.median(concatenate_date['Value']))
# Out:
# 4674631895.375934
# 605561732.178615

# %%
# Show the distribution for the 'Value column

from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns
sns.distplot(concatenate_date['Value'], kde=True)
plt.title('Colum Value Distribution')
plt.xlabel('Value')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\TOSHIBA\AppData\Local\Temp\ipykernel_10124\1401654984.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(concatenate_date['Value'], kde=True)

# %%
# Display Boxpolt to determinate outliers
import seaborn as sns
sns.boxplot(concatenate_date['Value'])
# Out:
# <Axes: >

# %%
# Eliminate outliers to avoid interference in the model
import numpy as np
q1,q3 = np.percentile(concatenate_date['Value'],[25,75])
print(q1,q3)
# Out:
# 137572006.85 1843985724.90325

# %%
# Verify outliers (Lower limit- Higher limit)
IQR = q3-q1
lower_limit = q1-1.5*(IQR)
higher_limit = q3+1.5*(IQR)
print(lower_limit,higher_limit)
# Out:
# -2422048570.229875 4403606301.983125

# %%
selection =

# %%
# Remove outliers

# %%
statistics.variance(concatenate_date['Value'])
